# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = [[1, [(820,256),(2500,836),(2090,713),(410,133)]],
       [10, [(820,256),(2500,834),(2090,711),(410,133)]], 
       [100, [(820,256),(2500,834),(2090,711),(410,133)]],
       [1000,[(820,242),(2500,804),(2090,689),(410,126)]],
       [10000,[(820,42),(2500,130),(2090,112),(410,22)]]]

for index in np.arange(0,5):
    print ("Error tolerance ", data[index][0])
    plt.bar(np.arange(0,4), [value[0] for value in data[index][1]], color='r')
    plt.bar(np.arange(0,4), [value[1] for value in data[index][1]], color='g')
    plt.show()
# Out:
# Error tolerance  1
# Error tolerance  10
# Error tolerance  100
# Error tolerance  1000
# Error tolerance  10000
